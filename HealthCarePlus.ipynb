-- %% [markdown]
-- # [Healthcareplus]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Healthcareplus]    Script Date: 23.06.2024 23:25:42 ******/
CREATE DATABASE [Healthcareplus]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Healthcareplus_Data', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Healthcareplus.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 1024KB )
 LOG ON 
( NAME = N'Healthcareplus_Log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Healthcareplus.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 10%)
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Healthcareplus] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Healthcareplus].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Healthcareplus] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Healthcareplus] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Healthcareplus] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Healthcareplus] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Healthcareplus] SET ARITHABORT OFF 
GO
ALTER DATABASE [Healthcareplus] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Healthcareplus] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Healthcareplus] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Healthcareplus] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Healthcareplus] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Healthcareplus] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Healthcareplus] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Healthcareplus] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Healthcareplus] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Healthcareplus] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Healthcareplus] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Healthcareplus] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Healthcareplus] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Healthcareplus] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Healthcareplus] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Healthcareplus] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Healthcareplus] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Healthcareplus] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Healthcareplus] SET  MULTI_USER 
GO
ALTER DATABASE [Healthcareplus] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Healthcareplus] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Healthcareplus] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Healthcareplus] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Healthcareplus] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Healthcareplus] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Healthcareplus] SET QUERY_STORE = ON
GO
ALTER DATABASE [Healthcareplus] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Appointment_Charges]

-- %%
USE [Healthcareplus]
GO

-- %%
/****** Object:  Table [dbo].[Appointment_Charges]    Script Date: 23.06.2024 23:25:42 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Appointment_Charges](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[title] [varchar](150) NOT NULL,
	[amount] [float] NOT NULL,
	[appointment_id] [bigint] NOT NULL,
 CONSTRAINT [PK_Appointment_Charges] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Appointments]

-- %%
/****** Object:  Table [dbo].[Appointments]    Script Date: 23.06.2024 23:25:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Appointments](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[appt_number] [int] NOT NULL,
	[payment_status] [varchar](10) NOT NULL,
	[schedule_id] [bigint] NOT NULL,
	[patient_id] [bigint] NOT NULL,
	[created_at] [datetime] NOT NULL,
 CONSTRAINT [PK_Appoinments] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DoctorProfiles]

-- %%
/****** Object:  Table [dbo].[DoctorProfiles]    Script Date: 23.06.2024 23:25:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DoctorProfiles](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[qualification] [varchar](50) NOT NULL,
	[specialization] [varchar](100) NOT NULL,
	[contact_no] [varchar](12) NOT NULL,
	[location] [varchar](20) NOT NULL,
	[home_address] [varchar](150) NOT NULL,
	[hospital_address] [varchar](150) NOT NULL,
	[user_id] [bigint] NOT NULL,
 CONSTRAINT [PK_DoctorProfiles] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [CK_Contact_No] UNIQUE NONCLUSTERED 
(
	[contact_no] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patients]

-- %%
/****** Object:  Table [dbo].[Patients]    Script Date: 23.06.2024 23:25:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patients](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[first_name] [varchar](150) NOT NULL,
	[last_name] [varchar](150) NOT NULL,
	[email] [varchar](150) NOT NULL,
	[contact_no] [varchar](12) NOT NULL,
	[address] [varchar](150) NOT NULL,
	[disease] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Patients] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [CK_Patients_ContactNo] UNIQUE NONCLUSTERED 
(
	[contact_no] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Payments]

-- %%
/****** Object:  Table [dbo].[Payments]    Script Date: 23.06.2024 23:25:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Payments](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[payment_method] [varchar](50) NOT NULL,
	[total] [float] NOT NULL,
	[balance] [float] NULL,
	[status] [varchar](10) NOT NULL,
	[transaction_id] [varchar](150) NULL,
	[appointment_id] [bigint] NOT NULL,
	[created_at] [datetime] NOT NULL,
 CONSTRAINT [PK_Payments] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Schedules]

-- %%
/****** Object:  Table [dbo].[Schedules]    Script Date: 23.06.2024 23:25:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Schedules](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[doctor_id] [bigint] NOT NULL,
	[location] [varchar](50) NOT NULL,
	[room] [tinyint] NOT NULL,
	[start_date] [datetime] NOT NULL,
	[end_date] [datetime] NOT NULL,
	[updated_at] [timestamp] NULL,
 CONSTRAINT [PK_Schedules] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StaffProfiles]

-- %%
/****** Object:  Table [dbo].[StaffProfiles]    Script Date: 23.06.2024 23:25:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StaffProfiles](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[contact_no] [varchar](12) NOT NULL,
	[address] [varchar](150) NOT NULL,
	[user_id] [bigint] NOT NULL,
 CONSTRAINT [PK_StaffProfile] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [CK_StaffProfile_ContactNo] UNIQUE NONCLUSTERED 
(
	[contact_no] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 23.06.2024 23:25:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[first_name] [varchar](150) NOT NULL,
	[last_name] [varchar](150) NOT NULL,
	[email] [varchar](150) NOT NULL,
	[password] [varchar](200) NOT NULL,
	[role] [varchar](20) NOT NULL,
 CONSTRAINT [PK_Users] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [Unique_Email] UNIQUE NONCLUSTERED 
(
	[email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Appoinments_payment_status]

-- %%
ALTER TABLE [dbo].[Appointments] ADD  CONSTRAINT [DF_Appoinments_payment_status]  DEFAULT ('unpaid') FOR [payment_status]
GO

-- %% [markdown]
-- # [DF_Users_role]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_role]  DEFAULT ('patient') FOR [role]
GO

-- %% [markdown]
-- # [FK_Appointment_Charges_Appointments]

-- %%
ALTER TABLE [dbo].[Appointment_Charges]  WITH CHECK ADD  CONSTRAINT [FK_Appointment_Charges_Appointments] FOREIGN KEY([appointment_id])
REFERENCES [dbo].[Appointments] ([id])
GO
ALTER TABLE [dbo].[Appointment_Charges] CHECK CONSTRAINT [FK_Appointment_Charges_Appointments]
GO

-- %% [markdown]
-- # [FK_Appoinments_Patients]

-- %%
ALTER TABLE [dbo].[Appointments]  WITH CHECK ADD  CONSTRAINT [FK_Appoinments_Patients] FOREIGN KEY([patient_id])
REFERENCES [dbo].[Patients] ([id])
GO
ALTER TABLE [dbo].[Appointments] CHECK CONSTRAINT [FK_Appoinments_Patients]
GO

-- %% [markdown]
-- # [FK_Appoinments_Schedules]

-- %%
ALTER TABLE [dbo].[Appointments]  WITH CHECK ADD  CONSTRAINT [FK_Appoinments_Schedules] FOREIGN KEY([schedule_id])
REFERENCES [dbo].[Schedules] ([id])
GO
ALTER TABLE [dbo].[Appointments] CHECK CONSTRAINT [FK_Appoinments_Schedules]
GO

-- %% [markdown]
-- # [FK_DoctorProfiles_Users]

-- %%
ALTER TABLE [dbo].[DoctorProfiles]  WITH CHECK ADD  CONSTRAINT [FK_DoctorProfiles_Users] FOREIGN KEY([user_id])
REFERENCES [dbo].[Users] ([id])
GO
ALTER TABLE [dbo].[DoctorProfiles] CHECK CONSTRAINT [FK_DoctorProfiles_Users]
GO

-- %% [markdown]
-- # [FK_Payments_Appointments]

-- %%
ALTER TABLE [dbo].[Payments]  WITH CHECK ADD  CONSTRAINT [FK_Payments_Appointments] FOREIGN KEY([appointment_id])
REFERENCES [dbo].[Appointments] ([id])
GO
ALTER TABLE [dbo].[Payments] CHECK CONSTRAINT [FK_Payments_Appointments]
GO

-- %% [markdown]
-- # [FK_Schedules_Users]

-- %%
ALTER TABLE [dbo].[Schedules]  WITH CHECK ADD  CONSTRAINT [FK_Schedules_Users] FOREIGN KEY([doctor_id])
REFERENCES [dbo].[Users] ([id])
GO
ALTER TABLE [dbo].[Schedules] CHECK CONSTRAINT [FK_Schedules_Users]
GO

-- %% [markdown]
-- # [FK_StaffProfile_Users]

-- %%
ALTER TABLE [dbo].[StaffProfiles]  WITH CHECK ADD  CONSTRAINT [FK_StaffProfile_Users] FOREIGN KEY([user_id])
REFERENCES [dbo].[Users] ([id])
GO
ALTER TABLE [dbo].[StaffProfiles] CHECK CONSTRAINT [FK_StaffProfile_Users]
GO

-- %% [markdown]
-- # [Healthcareplus]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Healthcareplus] SET  READ_WRITE 
GO
